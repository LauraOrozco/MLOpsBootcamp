# %% [markdown]
# # MLOps con MLflow

# %% [markdown]
# #### Obtener datos

# %%
# load the dataset from pycaret
from pycaret.datasets import get_data
data = get_data('diamond')
# Out:
#    Carat Weight    Cut Color Clarity Polish Symmetry Report  Price
# 0          1.10  Ideal     H     SI1     VG       EX    GIA   5169
# 1          0.83  Ideal     H     VS1     ID       ID   AGSL   3470
# 2          0.85  Ideal     H     SI1     EX       EX    GIA   3183
# 3          0.91  Ideal     E     SI1     VG       VG    GIA   4370
# 4          0.83  Ideal     G     SI1     EX       EX    GIA   3171

# %% [markdown]
# #### Preprocesamiento

# %%
# initialize setup
from pycaret.regression import *
s = setup(data, target = 'Price', 
          transform_target = True, 
          log_experiment = True, 
          log_plots = True,
          experiment_name = 'diamond',
         silent = True)
# Out:
# <style type="text/css">
# #T_492e7_row17_col1, #T_492e7_row42_col1, #T_492e7_row56_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_492e7">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_492e7_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_492e7_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_492e7_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_492e7_row0_col0" class="data row0 col0" >session_id</td>
#       <td id="T_492e7_row0_col1" class="data row0 col1" >2292</td>
#     </tr>
#     <tr>
#       <th id="T_492e7_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_492e7_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_492e7_row1_col1" class="data row1 col1" >Price</td>
#     </tr>
#     <tr>
#       <th id="T_492e7_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_492e7_row2_col0" class="data row2 col0" >Original Data</td>
#       <td id="T_492e7_row2_col1" class="data row2 col1" >(6000, 8)</td>
#     </tr>
#     <tr>
#       <th id="T_492e7_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_492e7_row3_col0" class="data row3 col0" >Missing Values</td>
#       <td id="T_492e7_row3_col1" class="data row3 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_492e7_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_492e7_row4_col0" class="data row4 col0" >Numeric Features</td>
#       <td id="T_492e7_row4_col1" class="data row4 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_492e7_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_492e7_row5_col0" class="data row5 col0" >Categorical Features</td>
#       <td id="T_492e7_row5_col1" class="data row5 col1" >6</td>
#     </tr>
#     <tr>
#       <th id="T_492e7_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_492e7_row6_col0" class="data row6 col0" >Ordinal Features</td>
#       <td id="T_492e7_row6_col1" class="data row6 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_492e7_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_492e7_row7_col0" class="data row7 col0" >High Cardinality Features</td>
#       <td id="T_492e7_row7_col1" class="data row7 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_492e7_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_492e7_row8_col0" class="data row8 col0" >High Cardinality Method</td>
#       <td id="T_492e7_row8_col1" class="data row8 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_492e7_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_492e7_row9_col0" class="data row9 col0" >Transformed Train Set</td>
#       <td id="T_492e7_row9_col1" class="data row9 col1" >(4199, 28)</td>
#     </tr>
#     <tr>
#       <th id="T_492e7_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_492e7_row10_col0" class="data row10 col0" >Transformed Test Set</td>
#       <td id="T_492e7_row10_col1" class="data row10 col1" >(1801, 28)</td>
#     </tr>
#     <tr>
#       <th id="T_492e7_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_492e7_row11_col0" class="data row11 col0" >Shuffle Train-Test</td>
#       <td id="T_492e7_row11_col1" class="data row11 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_492e7_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_492e7_row12_col0" class="data row12 col0" >Stratify Train-Test</td>
#       <td id="T_492e7_row12_col1" class="data row12 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_492e7_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_492e7_row13_col0" class="data row13 col0" >Fold Generator</td>
#       <td id="T_492e7_row13_col1" class="data row13 col1" >KFold</td>
#     </tr>
#     <tr>
#       <th id="T_492e7_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_492e7_row14_col0" class="data row14 col0" >Fold Number</td>
#       <td id="T_492e7_row14_col1" class="data row14 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_492e7_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_492e7_row15_col0" class="data row15 col0" >CPU Jobs</td>
#       <td id="T_492e7_row15_col1" class="data row15 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_492e7_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_492e7_row16_col0" class="data row16 col0" >Use GPU</td>
#       <td id="T_492e7_row16_col1" class="data row16 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_492e7_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_492e7_row17_col0" class="data row17 col0" >Log Experiment</td>
#       <td id="T_492e7_row17_col1" class="data row17 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_492e7_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_492e7_row18_col0" class="data row18 col0" >Experiment Name</td>
#       <td id="T_492e7_row18_col1" class="data row18 col1" >diamond</td>
#     </tr>
#     <tr>
#       <th id="T_492e7_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_492e7_row19_col0" class="data row19 col0" >USI</td>
#       <td id="T_492e7_row19_col1" class="data row19 col1" >12ef</td>
#     </tr>
#     <tr>
#       <th id="T_492e7_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_492e7_row20_col0" class="data row20 col0" >Imputation Type</td>
#       <td id="T_492e7_row20_col1" class="data row20 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_492e7_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_492e7_row21_col0" class="data row21 col0" >Iterative Imputation Iteration</td>
#       <td id="T_492e7_row21_col1" class="data row21 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_492e7_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_492e7_row22_col0" class="data row22 col0" >Numeric Imputer</td>
#       <td id="T_492e7_row22_col1" class="data row22 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_492e7_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_492e7_row23_col0" class="data row23 col0" >Iterative Imputation Numeric Model</td>
#       <td id="T_492e7_row23_col1" class="data row23 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_492e7_level0_row24" class="row_heading level0 row24" >24</th>
#       <td id="T_492e7_row24_col0" class="data row24 col0" >Categorical Imputer</td>
#       <td id="T_492e7_row24_col1" class="data row24 col1" >constant</td>
#     </tr>
#     <tr>
#       <th id="T_492e7_level0_row25" class="row_heading level0 row25" >25</th>
#       <td id="T_492e7_row25_col0" class="data row25 col0" >Iterative Imputation Categorical Model</td>
#       <td id="T_492e7_row25_col1" class="data row25 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_492e7_level0_row26" class="row_heading level0 row26" >26</th>
#       <td id="T_492e7_row26_col0" class="data row26 col0" >Unknown Categoricals Handling</td>
#       <td id="T_492e7_row26_col1" class="data row26 col1" >least_frequent</td>
#     </tr>
#     <tr>
#       <th id="T_492e7_level0_row27" class="row_heading level0 row27" >27</th>
#       <td id="T_492e7_row27_col0" class="data row27 col0" >Normalize</td>
#       <td id="T_492e7_row27_col1" class="data row27 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_492e7_level0_row28" class="row_heading level0 row28" >28</th>
#       <td id="T_492e7_row28_col0" class="data row28 col0" >Normalize Method</td>
#       <td id="T_492e7_row28_col1" class="data row28 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_492e7_level0_row29" class="row_heading level0 row29" >29</th>
#       <td id="T_492e7_row29_col0" class="data row29 col0" >Transformation</td>
#       <td id="T_492e7_row29_col1" class="data row29 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_492e7_level0_row30" class="row_heading level0 row30" >30</th>
#       <td id="T_492e7_row30_col0" class="data row30 col0" >Transformation Method</td>
#       <td
# 2022/05/17 12:41:49 INFO mlflow.tracking.fluent: Experiment with name 'diamond' does not exist. Creating a new experiment.

# %% [markdown]
# #### Entrenamiento de modelos

# %%
# compare all models
best = compare_models()
# Out:
# <style type="text/css">
# #T_60994 th {
#   text-align: left;
# }
# #T_60994_row0_col0, #T_60994_row0_col1, #T_60994_row0_col5, #T_60994_row0_col6, #T_60994_row1_col0, #T_60994_row1_col2, #T_60994_row1_col3, #T_60994_row1_col4, #T_60994_row2_col0, #T_60994_row2_col1, #T_60994_row2_col2, #T_60994_row2_col3, #T_60994_row2_col4, #T_60994_row2_col5, #T_60994_row2_col6, #T_60994_row3_col0, #T_60994_row3_col1, #T_60994_row3_col2, #T_60994_row3_col3, #T_60994_row3_col4, #T_60994_row3_col5, #T_60994_row3_col6, #T_60994_row4_col0, #T_60994_row4_col1, #T_60994_row4_col2, #T_60994_row4_col3, #T_60994_row4_col4, #T_60994_row4_col5, #T_60994_row4_col6, #T_60994_row5_col0, #T_60994_row5_col1, #T_60994_row5_col2, #T_60994_row5_col3, #T_60994_row5_col4, #T_60994_row5_col5, #T_60994_row5_col6, #T_60994_row6_col0, #T_60994_row6_col1, #T_60994_row6_col2, #T_60994_row6_col3, #T_60994_row6_col4, #T_60994_row6_col5, #T_60994_row6_col6, #T_60994_row7_col0, #T_60994_row7_col1, #T_60994_row7_col2, #T_60994_row7_col3, #T_60994_row7_col4, #T_60994_row7_col5, #T_60994_row7_col6, #T_60994_row8_col0, #T_60994_row8_col1, #T_60994_row8_col2, #T_60994_row8_col3, #T_60994_row8_col4, #T_60994_row8_col5, #T_60994_row8_col6, #T_60994_row9_col0, #T_60994_row9_col1, #T_60994_row9_col2, #T_60994_row9_col3, #T_60994_row9_col4, #T_60994_row9_col5, #T_60994_row9_col6, #T_60994_row10_col0, #
>0.1010</td>
#     </tr>
#     <tr>
#       <th id="T_60994_level0_row3" class="row_heading level0 row3" >et</th>
#       <td id="T_60994_row3_col0" class="data row3 col0" >Extra Trees Regressor</td>
#       <td id="T_60994_row3_col1" class="data row3 col1" >752.9758</td>
#       <td id="T_60994_row3_col2" class="data row3 col2" >2630403.4464</td>
#       <td id="T_60994_row3_col3" class="data row3 col3" >1592.0587</td>
#       <td id="T_60994_row3_col4" class="data row3 col4" >0.9749</td>
#       <td id="T_60994_row3_col5" class="data row3 col5" >0.0799</td>
#       <td id="T_60994_row3_col6" class="data row3 col6" >0.0586</td>
#       <td id="T_60994_row3_col7" class="data row3 col7" >0.3230</td>
#     </tr>
#     <tr>
#       <th id="T_60994_level0_row4" class="row_heading level0 row4" >rf</th>
#       <td id="T_60994_row4_col0" class="data row4 col0" >Random Forest Regressor</td>
#       <td id="T_60994_row4_col1" class="data row4 col1" >746.7811</td>
#       <td id="T_60994_row4_col2" class="data row4 col2" >2663036.1460</td>
#       <td id="T_60994_row4_col3" class="data row4 col3" >1597.8634</td>
#       <td id="T_60994_row4_col4" class="data row4 col4" >0.9747</td>
#       <td id="T_60994_row4_col5" class="data row4 col5" >0.0789</td>
#       <td id="T_60994_row4_col6" class="data row4 col6" >0.0573</td>
#       <td id="T_60994_row4_col7" class="data row4 col7" >0.2720</td>
#     </tr>
#     <tr>
#       <th id="T_60994_level0_row5" class="row_heading level0 row5" >dt</th>
#       <td id="T_60994_row5_col0" class="data row5 col0" >Decision Tree Regressor</td>
#       <td id="T_60994_row5_col1" class="data row5 col1" >965.3726</td>
#       <td id="T_60994_row5_col2" class="data row5 col2" >4116269.9256</td>
#       <td id="T_60994_row5_col3" class="data row5 col3" >1995.2453</td>
#       <td id="T_60994_row5_col4" class="data row5 col4" >0.9601</td>
#       <td id="T_60994_row5_col5" class="data row5 col5" >0.1029</td>
#       <td id="T_60994_row5_col6" class="data row5 col6" >0.0747</td>
#       <td id="T_60994_row5_col7" class="d

# %%
# check the residuals of trained model
plot_model(best, plot = 'residuals')
# Out:
# VBox(children=(HBox(children=(TukeyAnscombeWidget({
#     'data': [{'hovertemplate': 'Split=train<br>Predictions…

# %%
# check feature importance
plot_model(best, plot = 'feature')

# %%
# finalize the model
final_best = finalize_model(best)

# save model to disk
save_model(final_best, 'diamond-pipeline')
# Out:
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=None,
#           steps=[('dtypes',
#                   DataTypes_Auto_infer(categorical_features=[],
#                                        display_types=False, features_todrop=[],
#                                        id_columns=[], ml_usecase='regression',
#                                        numerical_features=[], target='Price',
#                                        time_features=[])),
#                  ('imputer',
#                   Simple_Imputer(categorical_strategy='not_available',
#                                  fill_value_categorical=None,
#                                  fill_value_numerical=None,
#                                  numeric_strategy=...
#                                                   learning_rate=None,
#                                                   max_bin=None,
#                                                   max_cat_to_onehot=None,
#                                                   max_delta_step=None,
#                                                   max_depth=None,
#                                                   max_leaves=None,
#                                                   min_child_weight=None,
#                                                   missing=nan,
#                                                   monotone_constraints=None,
#                                                   n_estimators=100, n_jobs=-1,
#                                                   num_parallel_tree=None,
#                                                   objective='reg:squarederror',
#                                                   power_transformer_method='box-cox',
#                                                   power_transformer_standardize=True,
#                                                   predictor=None, ...)]],
#           verbose=False),
#  'diamond-pipeline.pkl')

# %% [markdown]
# ###  Gestión de modelos con MLFlow

# %%
# within notebook (notice ! sign infront)
# !mlflow ui

# %%
#localhost:5000

# %% [markdown]
# ### Consumir el modelo

# %%
import mlflow
logged_model = 'runs:/6bd4999886b9488fb6edd3ac4ab2af00/model/'

# Load model as a PyFuncModel.
loaded_model = mlflow.pyfunc.load_model(logged_model)

# Predict on a Pandas DataFrame.
import pandas as pd
loaded_model.predict(pd.DataFrame(data))

# %%
# print pipeline
print(loaded_model)

# %%
pipeline = load_model('C:/Users/Leyre/Desktop/Curso Mondragon/Curso_ML con Pycaret/Entrega/5. MLOps/mlruns/1/23c33b7efc8341ee823759c7c41b2293/artifacts/model/model')

# %%
# print pipeline
print(pipeline)

# %%
data = get_data('diamond')

# create a copy of data and drop Price
data2 = data.copy()
data2.drop('Price', axis=1, inplace=True)

# %%
# generate predictions
from pycaret.regression import predict_model
predictions = predict_model(pipeline, data=data2)
predictions.head()
